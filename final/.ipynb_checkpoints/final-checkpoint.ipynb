# %% [markdown]
# # graph Laplacian

# %% [markdown]
# Compute the unnormalized Laplacian of the graph below.
#
# Which of the features f1, f2, or f3, are likely to load to the low eigenvalued eigenvectors of the Laplacian?

# %% [markdown]
# ![image.png](attachment:image.png)
